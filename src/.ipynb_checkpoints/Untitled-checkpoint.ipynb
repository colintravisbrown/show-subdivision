# %%
from subprocess import Popen, PIPE, STDOUT
import os
p=Popen(['chimerax','-i'], stdout=PIPE, stdin=PIPE, stderr=PIPE)
print(p.stdin)
p.stdin.flush()
print(p.stdin)
p.stdin.write(b'--nogui --offscreen\n')
print(p.stdin)

# %%
import src

# %%
#default values
rdefault=1
sfdefalt=1
latdefault= 'hexagonal'
oridefault= 'n25r'

#h
while True:
    try:
        h=int(input("Enter the h-value for the capsid: "))
    except ValueError:
        print("Invalid input")
        continue
    else:
        break
#k        
while True:
    try:
        k=int(input("Enter the k-value for the capsid: "))
    except ValueError:
        print("Invalid input")
        continue
    else:
        break
        
#radius: r, rdefualt      
while True:
    rawr=input("Enter the radius for the capsid (nm) or n for default: ")
    if rawr in ['n', 'N']:
        r=rdefault
        print('r= default radius ', +[rdefault])
        break
    try:
        r=float(rawr)
    except ValueError:
        print("Invalid input")
        continue
    else:
        break
        
#sphere factor: sf, sfdefault
while True:
    rawsf=input("Enter the sphere factor for the capsid or n for default: ")
    if rawsf in ['n', 'N']:
        sf=sfdefault
        print('sf= default sf ', +[sfdefault])
        break
    try:
        sf=float(rawsf)
    except ValueError:
        print("Invalid input")
        continue
    else:
        break
#lattice type: lat, latdefault
while True:
    rawlat=input("Enter the lattice type or n for default: ")
    if rawlat in ['n', 'N']:
        lat=latdefault
        print('lat= default lat hexagonal')
        break
    try:
        lat=str(rawlat)
    except ValueError:
        print("Invalid input")
        continue
    else:
        break
        
#orientation: ori,oridefault              
while True:
    rawori=input("Enter the orientation for the capsid or n for default: ")
    if rawori in ['n', 'N']:
        ori=oridefault
        print('ori= default orientation n25r')
        break
    try:
        ori=str(rawori)
    except ValueError:
        print("Invalid input")
        continue
    else:
        break
